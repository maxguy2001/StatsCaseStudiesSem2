# %%
#katrina's notebook
import pandas as pd
import functions as func

# %%
df = pd.read_csv("houseprices.csv")

# %%
df = func.tidyData(df)
df.head()
# Out:
#    Id  LotArea Street LotShape LandContour Utilities Neighborhood BldgType  \
# 0   1     8450   Pave      Reg         Lvl    AllPub      CollgCr     1Fam
# 1   2     9600   Pave      Reg         Lvl    AllPub      Veenker     1Fam
# 2   3    11250   Pave      IR1         Lvl    AllPub      CollgCr     1Fam
# 3   4     9550   Pave      IR1         Lvl    AllPub      Crawfor     1Fam
# 4   5    14260   Pave      IR1         Lvl    AllPub      NoRidge     1Fam
#
#   HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0     2Story            7  ...             3             1          Gd
# 1     1Story            6  ...             3             1          TA
# 2     2Story            7  ...             3             1          Gd
# 3     2Story            7  ...             3             1          Gd
# 4     2Story            8  ...             4             1          Gd
#
#   TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  YrSold  SalePrice
# ...

# %%
scores = func.fitNaiveBayes(df, func.brierScore)
scores
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-bdec87007f0c> in <module>
# ----> 1 scores = func.fitNaiveBayes(df, func.brierScore)
#       2 scores
#
# ~/Documents/University/Year 4/StatsCaseStudiesSem1/sem2part1/StatsCaseStudiesSem2/Part1/functions.py in fitNaiveBayes(df, scoringFunction)
#     122
#     123         # Predict the response for test dataset
# --> 124         y_pred = gnb.predict_proba(X_test)
#     125
#     126         # score fit
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in predict_proba(self, X)
#     116             order, as they appear in the attribute :term:`classes_`.
#     117         """
# --> 118         return np.exp(self.predict_log_proba(X))
#     119
#     120
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in predict_log_proba(self, X)
#      96         check_is_fitted(self)
# ...
