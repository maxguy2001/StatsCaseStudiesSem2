# %%
#kim's notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("houseprices.csv")


oddsales = df[(df['SalePrice'] >= 500000)]
print(df["LotArea"].mean())
oddsales
# Out:
# 10516.828082191782
#         Id  LotArea Street LotShape LandContour Utilities Neighborhood  \
# 178    179    17423   Pave      IR1         Lvl    AllPub      StoneBr
# 440    441    15431   Pave      Reg         Lvl    AllPub      NridgHt
# 691    692    21535   Pave      IR1         Lvl    AllPub      NoRidge
# 769    770    53504   Pave      IR2         HLS    AllPub      StoneBr
# 803    804    13891   Pave      Reg         Lvl    AllPub      NridgHt
# 898    899    12919   Pave      IR1         Lvl    AllPub      NridgHt
# 1046  1047    16056   Pave      IR1         Lvl    AllPub      StoneBr
# 1169  1170    35760   Pave      IR1         Lvl    AllPub      NoRidge
# 1182  1183    15623   Pave      IR1         Lvl    AllPub      NoRidge
#
#      BldgType HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr  \
# 178      1Fam     1Story            9  ...             1             1
# 440      1Fam     1Story           10  ...             2             1
# 691      1Fam     2Story           10  ...             4             1
# 769      1Fam     2Story            8  ...             4             1
# 803      1Fam     2Story            9  ...             4             1
# 898      1Fam     1Story            9  ...             2             1
# 1046     1Fam     2Story            9  ...             4             1
# 1169     1Fam     2Story           10  ...             4             1
# 1182     1Fam     2Story           10  ...             4             1
#
#      KitchenQual TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  \
# 178           Ex            9           1     Attchd       1166      7
# 440           Ex           10           2     Attchd        672      4
# 691           Ex           10           2     Attchd        832      1
# 769           Ex           12           1    BuiltIn        841      6
# 803           Ex           12           1    BuiltIn       1020      1
# 898           Ex           11           2     Attchd        820      3
# 1046          Ex           11           1    BuiltIn        716      7
# 1169          Gd           10           1     Attchd        807      7
# 1182          Ex           10           2     Attchd        813      7
#
#       YrSold  SalePrice
# 178     2009     501837
# 440     2009     555000
# 691     2007     755000
# 769     2010     538000
# 803     2009     582933
# 898     2010     611657
# 1046    2006     556581
# 1169    2006     625000
# 1182    2007     745000
#
# [9 rows x 31 columns]

# %%
#Plot for House Sales Price, showing the mean of the values
plt.plot(df.SalePrice, color = 'g', linestyle = " ", marker = ".")
plt.axhline(y=np.mean(df.SalePrice), color = 'r', linestyle = '-')
plt.show()

print(np.mean(df.SalePrice))
# Out:
# 180921.19589041095

# %%
plt.plot(df.SalePrice, color = 'g', linestyle = " ", marker = ".")
plt.axhline(y=np.mean(df.SalePrice), color = 'r', linestyle = '-')
plt.show()

# %%
#Lot area does not show much impact on sale price apart from a few outliers
#TODO: investigate large plot areas

plt.scatter(df.SalePrice, df.LotArea, color = 'g', marker = ".")
plt.show()


oddArea = df[(df['LotArea'] >= 50000)]
oddArea
# Out:
#         Id  LotArea Street LotShape LandContour Utilities Neighborhood  \
# 53      54    50271   Pave      IR1         Low    AllPub      Veenker
# 249    250   159000   Pave      IR2         Low    AllPub      ClearCr
# 313    314   215245   Pave      IR3         Low    AllPub       Timber
# 335    336   164660   Grvl      IR1         HLS    AllPub       Timber
# 384    385    53107   Pave      IR2         Low    AllPub      ClearCr
# 451    452    70761   Pave      IR1         Low    AllPub      ClearCr
# 457    458    53227   Pave      IR1         Low    AllPub      ClearCr
# 706    707   115149   Pave      IR2         Low    AllPub      ClearCr
# 769    770    53504   Pave      IR2         HLS    AllPub      StoneBr
# 1298  1299    63887   Pave      IR3         Bnk    AllPub      Edwards
# 1396  1397    57200   Pave      IR1         Bnk    AllPub       Timber
#
#      BldgType HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr  \
# 53       1Fam     1Story            9  ...             0             1
# 249      1Fam     1.5Fin            6  ...             4             1
# 313      1Fam     1Story            7  ...             3             1
# 335    2fmCon     1.5Fin            5  ...             3             1
# 384      1Fam     2Story            6  ...             3             1
# 451      1Fam     1Story            7  ...             2             1
# 457      1Fam     1Story            4  ...             2             1
# 706      1Fam     1Story            7  ...             2             1
# 769      1Fam     2Story            8  ...             4             1
# 1298     1Fam     2Story           10  ...             3             1
# 1396     1Fam     1Story            5  ...             3             1
#
#      KitchenQual TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  \
# 53            Gd            5           1     Attchd        894     11
# 249           Gd            7           2     Attchd        389      6
# 313           TA            8           2     Attchd        513      6
# 335           TA            7           2     Attchd        529      8
# 384           Gd            9           2     Attchd        501      6
# 451           Gd            5           2     Attchd        576     12
# 457           Gd            6           2     Attchd        529      3
# 706           Gd            5           2     Attchd        739      6
# 769           Ex           12           1    BuiltIn        841      6
# 1298          Ex           12           3     Attchd       1418      1
# 1396          TA            7           2     Detchd        572      6
#
#       YrSold  SalePrice
# 53      2006     385000
# 249     2007     277000
# 313     2009     375000
# 335     2008     228950
# 384     2007     240000
# 451     2006     280000
# 457     2008     256000
# 706     2007     302000
# 769     2010     538000
# 1298    2008     160000
# 1396    2010     160000
#
# [11 rows x 31 columns]

# %%
#Neighbourhood good, shows each house in each neighbourhood are similar
plt.scatter(df.SalePrice, df.Neighborhood) 
plt.show()

# %%
# good plot, same as before
#plt.scatter(df.SalePrice, df.BldgType) 
#TODO: make into boxplot

#plt.boxplot(df.BldgType, df.SalePrice)
#plt.show()

# %%
#THIS IS WRONG - HELP
#Maybe not a big detering fctor, as many are still around the same price no matter the price
plt.scatter(df.OverallCond, df.SalePrice)
plt.show() 



if df.OverallCond = 1:
    c1 =
# Out:
#   File "<ipython-input-235-b4f06bede509>", line 8
#     if df.OverallCond = 1:
#                       ^
# SyntaxError: invalid syntax
