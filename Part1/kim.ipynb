# %%
#kim's notebook


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("houseprices.csv")
print(df.head)


oddsales = df[(df['SalePrice'] >= 700000)]
# Out:
# <bound method NDFrame.head of         Id  LotArea Street LotShape LandContour Utilities Neighborhood  \
# 0        1     8450   Pave      Reg         Lvl    AllPub      CollgCr
# 1        2     9600   Pave      Reg         Lvl    AllPub      Veenker
# 2        3    11250   Pave      IR1         Lvl    AllPub      CollgCr
# 3        4     9550   Pave      IR1         Lvl    AllPub      Crawfor
# 4        5    14260   Pave      IR1         Lvl    AllPub      NoRidge
# ...    ...      ...    ...      ...         ...       ...          ...
# 1455  1456     7917   Pave      Reg         Lvl    AllPub      Gilbert
# 1456  1457    13175   Pave      Reg         Lvl    AllPub       NWAmes
# 1457  1458     9042   Pave      Reg         Lvl    AllPub      Crawfor
# 1458  1459     9717   Pave      Reg         Lvl    AllPub        NAmes
# 1459  1460     9937   Pave      Reg         Lvl    AllPub      Edwards
#
#      BldgType HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr  \
# 0        1Fam     2Story            7  ...             3             1
# 1        1Fam     1Story            6  ...             3             1
# 2        1Fam     2Story            7  ...             3             1
# 3        1Fam     2Story            7  ...             3             1
# 4        1Fam     2Story            8  ...             4             1
# ...       ...        ...          ...  ...           ...           ...
# 1455     1Fam     2Story            6  ...             3             1
# 1456     1Fam     1Story            6  ...             3             1
# 1457     1Fam     2Story            7  ...             4             1
# 1458     1Fam     1Story            5  ...             2             1
# 1459     1Fam     1Story            5  ...             3             1
#
#      KitchenQual TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  \
# 0             Gd            8           0     Attchd        548      2
# 1             TA            6           1     Attchd        460      5
# 2             Gd            6           1     Attchd        608      9
# 3             Gd            7           1     Detchd        642      2
# 4             Gd            9           1     Attchd        836     12
# ...          ...          ...         ...        ...        ...    ...
# 1455          TA            7           1     Attchd        460      8
# 1456          TA            7           2     Attchd        500      2
# 1457          Gd            9           2     Attchd        252      5
# 1458          Gd            5           0     Attchd        240      4
# 1459          TA            6           0     Attchd        276      6
#
#       YrSold  SalePrice
# 0       2008     208500
# 1       2007     181500
# 2       2008     223500
# 3       2006     140000
# 4       2008     250000
# ...      ...        ...
# 1455    2007     175000
# 1456    2010     210000
# 1457    2010     266500
# 1458    2010     142125
# 1459    2008     147500
#
# [1460 rows x 31 columns]>

# %%
plt.plot(df.SalePrice)
plt.show()

# %%
#Lot area does not show much impact on sale price apart from a few outliers
plt.scatter(df.SalePrice, df.LotArea) 
plt.show()

# %%
#Neighbourhood good, shows each house in each neighbourhood are similar
plt.scatter(df.SalePrice, df.Neighborhood) 
plt.show()

# %%
# good plot, same as before
plt.scatter(df.SalePrice, df.BldgType) 
plt.show()

# %%
#Maybe not a big detering fctor, as many are still around the same price no matter the price
plt.scatter(df.SalePrice, df.OverallCond) 
plt.show()
