# %%
#import libraries
import functions as func
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
#from sklearn.feature_selection import SequentialFeatureSelector as sfs
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")

df = pd.read_csv("houseprices.csv") 
df.head()
# Out:
#    Id  LotArea Street LotShape LandContour Utilities Neighborhood BldgType  \
# 0   1     8450   Pave      Reg         Lvl    AllPub      CollgCr     1Fam
# 1   2     9600   Pave      Reg         Lvl    AllPub      Veenker     1Fam
# 2   3    11250   Pave      IR1         Lvl    AllPub      CollgCr     1Fam
# 3   4     9550   Pave      IR1         Lvl    AllPub      Crawfor     1Fam
# 4   5    14260   Pave      IR1         Lvl    AllPub      NoRidge     1Fam
#
#   HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0     2Story            7  ...             3             1          Gd
# 1     1Story            6  ...             3             1          TA
# 2     2Story            7  ...             3             1          Gd
# 3     2Story            7  ...             3             1          Gd
# 4     2Story            8  ...             4             1          Gd
#
#   TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  YrSold  SalePrice
# ...

# %%
import functions as func

df.dropna(inplace=True)
df = pd.get_dummies(df)

y = df["SalePrice"]
X = df.copy(deep=True)
X.drop(["SalePrice"], axis=1, inplace=True)

scores1 = []
scores2 = []
scores3 = []

for i in X.columns:
    k1 = X[[i]]  
    score1 = func.trainLinearRegression(k1, y)
    scores1.append([i, score1])

min_score1 = min(scores1)
print(min_score1[0])
first_variable = X[[min_score1[0]]]
X.drop([min_score1[0]], axis=1, inplace=True)

for j in X.columns:
    k2 = pd.DataFrame(X[[j]])
    k2.join(first_variable) 
    score2 = func.trainLinearRegression(k2, y)
    scores2.append([j, score2])

min_score2 = min(scores2)
print(min_score2[0])
second_variable = X[[min_score2[0]]]
X.drop([min_score2[0]], axis=1, inplace=True)

for k in X.columns:
    k3 = pd.DataFrame(X[[k]])
    k3.join(first_variable)
    k3.join(second_variable)
    score3 = func.trainLinearRegression(k3, y)
    scores3.append([k, score3])

min_score3 = min(scores3)
print(min_score3[0])

print(min_score1[0], min_score2[0], min_score3[0])
# Out:
# BedroomAbvGr
# BldgType_1Fam
# BldgType_2fmCon
# BedroomAbvGr BldgType_1Fam BldgType_2fmCon

# %%
# Out:
# Index(['Id', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'TotalBsmtSF', 'GrLivArea', 'FullBath', 'HalfBath', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageArea', 'MoSold', 'YrSold',
#        'Street_Grvl', 'Street_Pave', 'LotShape_IR1', 'LotShape_IR2',
#        'LotShape_IR3', 'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS',
#        'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub',
#        'Utilities_NoSeWa', 'Neighborhood_Blmngtn', 'Neighborhood_Blueste',
#        'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_ClearCr',
#        'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 'Neighborhood_Edwards',
#        'Neighborhood_Gilbert', 'Neighborhood_IDOTRR', 'Neighborhood_MeadowV',
#        'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NPkVill',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
#        'Neighborhood_OldTown', 'Neighborhood_SWISU', 'Neighborhood_Sawyer',
# ...
