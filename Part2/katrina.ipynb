# %%
#import libraries
import functions as func
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
#from sklearn.feature_selection import SequentialFeatureSelector as sfs
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")

df = pd.read_csv("houseprices.csv") 
df.head()
# Out:
#    Id  LotArea Street LotShape LandContour Utilities Neighborhood BldgType  \
# 0   1     8450   Pave      Reg         Lvl    AllPub      CollgCr     1Fam
# 1   2     9600   Pave      Reg         Lvl    AllPub      Veenker     1Fam
# 2   3    11250   Pave      IR1         Lvl    AllPub      CollgCr     1Fam
# 3   4     9550   Pave      IR1         Lvl    AllPub      Crawfor     1Fam
# 4   5    14260   Pave      IR1         Lvl    AllPub      NoRidge     1Fam
#
#   HouseStyle  OverallQual  ...  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0     2Story            7  ...             3             1          Gd
# 1     1Story            6  ...             3             1          TA
# 2     2Story            7  ...             3             1          Gd
# 3     2Story            7  ...             3             1          Gd
# 4     2Story            8  ...             4             1          Gd
#
#   TotRmsAbvGrd  Fireplaces GarageType GarageArea MoSold  YrSold  SalePrice
# ...

# %%
import functions as func

df.dropna(inplace=True)
df = pd.get_dummies(df)

y = df["SalePrice"]
X = df.copy(deep=True)
X.drop(["SalePrice"], axis=1, inplace=True)

scores1 = []
scores2 = []
scores3 = []

for i in X.columns:
    k1 = X[[i]]  
    score1 = func.trainLinearRegression(k1, y)
    scores1.append([i, score1])

min_score1 = min(scores1)
first_variable = X[[min_score1[0]]]
X.drop(min_score1[0], axis=1, inplace=True)

for i in X.columns:
    k2 = pd.concat(X[[i]], min_score1[0]) 
    score2 = func.trainLinearRegression(k2, y)
    scores2.append([i, score2])

min_score2 = min(scores2)
second_variable = X[[min_score2[0]]]
X.drop(min_score2[0], axis=1, inplace=True)

for i in X.columns:
    k3 = pd.concat(X[[i]], min_score1[0], min_score2[0])
    score3 = func.trainLinearRegression(k3, y)
    scores3.append([i, score3])

min_score3 = min(scores3)
third_variable = X[[min_score3[0]]]

print(first_variable, second_variable, third_variable)


# ADD FIRST_VARIABLE TO LINE
# iterate through all the variables 

# append score to a list, find the smallest, and then add that variable to the linear model and then loop through the rest

# model with 1 chosen variable
# repeat until 3 variables chosen.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-5015b32dfe4e> in <module>
#      22
#      23 for i in X.columns:
# ---> 24     k2 = X[[i, min_score1[0]]]
#      25     score2 = func.trainLinearRegression(k2, y)
#      26     scores2.append([i, score2])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# ...

# %%
# Out:
#       OverallCond  LotArea
# 0               5     8450
# 1               8     9600
# 2               5    11250
# 3               5     9550
# 4               5    14260
# ...           ...      ...
# 1455            5     7917
# 1456            6    13175
# 1457            9     9042
# 1458            6     9717
# 1459            6     9937
#
# [1378 rows x 2 columns]
